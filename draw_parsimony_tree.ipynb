# %%
from Bio import Phylo
from Bio.Phylo.TreeConstruction import DistanceMatrix, DistanceTreeConstructor
from keyname import keyname as kn
from matplotlib import colors as mpl_colors
from teeplot import teeplot as tp

import Bio
import alifedata_phyloinformatics_convert as apc
import csv
import glob
import itertools
import json
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import networkx as nx
import numpy as np
import pandas as pd
import scipy as sci
import seaborn as sns
import urllib.request as request
import io
from copy import deepcopy


from etlib.SortableTree.SortableTree import SortableTree, find_leaves
from etlib.PlotTools.PlotTools import enable_pretty_graphing, set_color
enable_pretty_graphing()

# %%
morphs = {x['stint']: x[' morph'][1:] for x in pd.read_csv('morphs_by_stint.csv').to_dict(orient='records')}

# %%
# store parsimony trees
pars_tree = Phylo.read("data/parsimony_tree.xml", "phyloxml")
sorted_pars_tree = Phylo.read("data/sorted_parsimony_tree.xml", "phyloxml")
ladderized_pars_tree = Phylo.read("data/ladderized_parsimony_tree.xml", "phyloxml")
rerooted_pars_tree = Phylo.read("data/rerooted_parsimony_tree.xml", "phyloxml")

# %%
# def name_function(node):
#     try:
#         return str(int(node.name)) + " (" + morphs[int(node.name)] + ")" if 'Inner' not in str(node) else None
#     except TypeError:
#         return ""
    
def name_function(node):
    if node.is_terminal():
        return str(int(node.name)) + " (" + morphs[int(node.name)] + ")"

# %%
tp.tee(
    Phylo.draw,
    pars_tree,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="parsimony_tree"
)
# Out:
# teeplots/parsimony_tree/viz=draw+ext=.pdf
# teeplots/parsimony_tree/viz=draw+ext=.png

# %%
tp.tee(
    Phylo.draw,
    sorted_pars_tree,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="sorted_parsimony_tree"
)
# Out:
# teeplots/sorted_parsimony_tree/viz=draw+ext=.pdf
# teeplots/sorted_parsimony_tree/viz=draw+ext=.png

# %%
tp.tee(
    Phylo.draw,
    ladderized_pars_tree,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="ladderized_parsimony_tree"
)
# Out:
# teeplots/ladderized_parsimony_tree/viz=draw+ext=.pdf
# teeplots/ladderized_parsimony_tree/viz=draw+ext=.png

# %%
tp.tee(
    Phylo.draw,
    rerooted_pars_tree,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="rerooted_parsimony_tree"
)
# Out:
# teeplots/rerooted_parsimony_tree/viz=draw+ext=.pdf
# teeplots/rerooted_parsimony_tree/viz=draw+ext=.png

# %%
pars_tree_no_outliers = deepcopy(pars_tree)
pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 0)
pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 1)
# Out:
# Clade(name='Inner76')

# %%
tp.tee(
    Phylo.draw,
    pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="parsimony_tree_no_outliers"
)
# Out:
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
sorted_pars_tree_no_outliers = deepcopy(sorted_pars_tree)
sorted_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 0)
sorted_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 1)
# Out:
# Clade(name='0000000002')

# %%
tp.tee(
    Phylo.draw,
    sorted_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="sorted_parsimony_tree_no_outliers"
)
# Out:
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
ladderized_pars_tree_no_outliers = deepcopy(ladderized_pars_tree)
ladderized_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 0)
ladderized_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 1)
# Out:
# Clade(name='0000000002')

# %%
tp.tee(
    Phylo.draw,
    ladderized_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="ladderized_parsimony_tree_no_outliers"
)
# Out:
# teeplots/ladderized_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/ladderized_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
rerooted_pars_tree_no_outliers = deepcopy(rerooted_pars_tree)
rerooted_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 0)
rerooted_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 1)
# Out:
# Clade(branch_length=0.0, name='0000000002')

# %%
tp.tee(
    Phylo.draw,
    rerooted_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="rerooted_parsimony_tree_no_outliers"
)
# Out:
# teeplots/rerooted_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/rerooted_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
ladderized_pars_tree_no_outliers = deepcopy(pars_tree)
ladderized_pars_tree_no_outliers.root_with_outgroup({"name": "0000000002"})
ladderized_pars_tree_no_outliers.ladderize(reverse=True)
ladderized_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 0)
ladderized_pars_tree_no_outliers.prune(target=lambda x: int(x.name) == 1)
# Out:
# Clade(branch_length=11.651452508776366, name='Inner81')

# %%
print(ladderized_pars_tree_no_outliers)
# Out:
# Phylogeny(rooted=True)
#     Clade(branch_length=0.0)
#         Clade(branch_length=0.0, name='0000000002')
#         Clade(branch_length=65.7265625, name='Inner4')
#             Clade(branch_length=33.2734375, name='0000000004')
#             Clade(branch_length=7.875672043010752, name='Inner5')
#                 Clade(branch_length=9.311842105263167, name='0000000003')
#                 Clade(branch_length=3.749327956989248, name='Inner7')
#                     Clade(branch_length=15.188157894736833, name='Inner3')
#                         Clade(branch_length=38.98453608247422, name='0000000008')
#                         Clade(branch_length=3.0154639175257785, name='Inner2')
#                             Clade(branch_length=9.602040816326536, name='0000000006')
#                             Clade(branch_length=15.397959183673464, name='0000000007')
#                     Clade(branch_length=17.637907608695656, name='Inner8')
# ...

# %%
tp.tee(
    Phylo.draw,
    ladderized_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="ladderized_parsimony_tree_no_outliers"
)
# Out:
# teeplots/ladderized_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/ladderized_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
tp.tee(
    Phylo.draw,
    sorted_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="sorted_parsimony_tree_no_outliers"
)
# Out:
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
sorted_pars_tree_no_outliers.ladderize()

# %%
tp.tee(
    Phylo.draw,
    sorted_pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="sorted_parsimony_tree_no_outliers"
)
# Out:
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/sorted_parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
tp.tee(
    Phylo.draw,
    pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="parsimony_tree_no_outliers"
)
# Out:
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
pars_tree_no_outliers.ladderize()

# %%
tp.tee(
    Phylo.draw,
    pars_tree_no_outliers,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="parsimony_tree_no_outliers"
)
# Out:
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.png

# %%
sorted_pars_tree = deepcopy(pars_tree)
sorted_pars_tree.prune(target=lambda x: int(x.name) == 0)
sorted_pars_tree.prune(target=lambda x: int(x.name) == 1)

sorted_pars_tree = SortableTree(sorted_pars_tree.clade)
sorted_pars_tree.fix_inner_nodes()
sorted_pars_tree.sort_tree(reverse=False)
# Out:
# before [SortableClade(branch_length=13.27006011169033, label='0000000002', name='0000000002'), SortableClade(branch_length=17.34004886945081, label='0000000069', name='0000000069')]
# after [SortableClade(branch_length=13.27006011169033, label='0000000002', name='0000000002'), SortableClade(branch_length=17.34004886945081, label='0000000069', name='0000000069')]
# before [SortableClade(branch_length=11.651452508776366, label='0000000002', name='0000000002'), SortableClade(branch_length=11.482325027775001, label='0000000063', name='0000000063')]
# after [SortableClade(branch_length=11.651452508776366, label='0000000002', name='0000000002'), SortableClade(branch_length=11.482325027775001, label='0000000063', name='0000000063')]
# before [SortableClade(branch_length=10.936845896826025, label='0000000002', name='0000000002'), SortableClade(branch_length=3.8124885884831556, label='0000000056', name='0000000056')]
# ...

# %%
tp.tee(
    Phylo.draw,
    sorted_pars_tree,
    label_func=name_function,
    branch_labels=None,
    label_colors=set_color,
    xlabel=["Phylogenetic Distance"],
    ylabel=[""],
    yticks={"ticks": [0]},
    grid={"visible": True, "which": "both", "axis": "x", "color": "gainsboro", "linewidth": "0.5"},
    do_show=False,
    teeplot_subdir="parsimony_tree_no_outliers"
)
# Out:
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.pdf
# teeplots/parsimony_tree_no_outliers/viz=draw+ext=.png
