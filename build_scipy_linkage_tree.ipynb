# %%
from Bio import Phylo
from Bio.Phylo.TreeConstruction import DistanceMatrix, DistanceTreeConstructor
from keyname import keyname as kn
from matplotlib import colors as mpl_colors
from teeplot import teeplot as tp

import Bio
import alifedata_phyloinformatics_convert as apc
import csv
import glob
import itertools
import json
import networkx as nx
import numpy as np
import pandas as pd
import scipy as sci
import seaborn as sns
import urllib.request as request
import io
from copy import deepcopy

from etlib.SortableTree.SortableTree import SortableTree, to_tril, fix_branch_length
from etlib.PlotTools.PlotTools import enable_pretty_graphing, set_color
enable_pretty_graphing()

# %%
morphs = {x['stint']: x[' morph'][1:] for x in pd.read_csv('morphs_by_stint.csv').to_dict(orient='records')}

# %%
matrix = np.loadtxt("data/distance_matrix.matrix")
with open("data/stint_tags.json", 'r') as f:
    stint_tags = json.loads(f.read())

# %%
linkage_matrix = sci.cluster.hierarchy.linkage(matrix)

# %%
dendropy_tree = apc.scipy_linkage_matrix_to_dendropy_tree(
    linkage_matrix,
    leaf_labels=['{} ({})'.format(str(x), morphs[x]) for x in range(len(linkage_matrix) + 1)]
)

# %%
df = apc.dendropy_tree_to_alife_dataframe(dendropy_tree)

# %%
tree = apc.alife_dataframe_to_biopython_tree(df, ['label'])

# %%
new_tree = SortableTree(root=tree.clade)
new_tree.fix_inner_nodes()

# %%
def fix_tree(root):
    for node in root:
        if node.label:
            node.name = node.label
        fix_tree(node)
fix_tree(new_tree.clade)

# %%
Phylo.write(new_tree, "data/scipy_linkage_tree.xml", "phyloxml")
# Out:
# 1

# %%
print(new_tree)
# Out:
# SortableTree(rooted=True)
#     Clade(id=0, label='0 (a)', origin_time=0.0)
#         SortableClade(id=1, label='0 (a)', name='0 (a)', origin_time=3824.5671650527984)
#             SortableClade(id=2, label='0 (a)', name='0 (a)', origin_time=3903.231006809987)
#             SortableClade(id=3, label='1 (b)', name='1 (b)', origin_time=3903.231006809987)
#         SortableClade(id=4, label='10 (b)', name='10 (b)', origin_time=3824.5671650527984)
#             SortableClade(id=5, label='100 (j)', name='100 (j)', origin_time=4137.762391708634)
#                 SortableClade(id=6, label='100 (j)', name='100 (j)', origin_time=4269.005486765098)
#                     SortableClade(id=7, label='100 (j)', name='100 (j)', origin_time=4384.258469372925)
#                         SortableClade(id=8, label='100 (j)', name='100 (j)', origin_time=4457.572860866001)
#                             SortableClade(id=9, label='82 (e)', name='82 (e)', origin_time=4494.325411797875)
#                                 SortableClade(id=10, label='82 (e)', name='82 (e)', origin_time=4519.074149139404)
#                                 SortableClade(id=11, label='83 (e)', name='83 (e)', origin_time=4519.074149139404)
#                                     SortableClade(id=12, label='88 (e)', name='88 (e)', origin_time=4538.529225597747)
#                                     SortableClade(id=13, label='83 (e)', name='83 (e)', origin_time=4538.529225597747)
#                                         SortableClade(id=14, label='85 (e)', name='85 (e)', origin_time=4550.456086039624)
#                                             SortableClade(id=15, label='85 (e)', name='85 (e)', origin_time=4558.137231787493)
#                                             SortableClade(id=16, label='86 (e)', name='86 (e)', origin_time=4558.137231787493)
#                                         SortableClade(id=17, label='83 (e)', name='83 (e)', origin_time=4550.456086039624)
#                                             SortableClade(id=18, label='83 (e)', name='83 (e)', origin_time=4560.567960247702)
#                                             SortableClade(id=19, label='84 (e)', name='84 (e)', origin_time=4560.567960247702)
#                             SortableClade(id=20, label='100 (j)', name='100 (j)', origin_time=4494.325411797875)
#                                 SortableClade(id=21, label='100 (j)', name='100 (j)', origin_time=4530.622794623638)
#                                     SortableClade(id=22, label='90 (g)', name='90 (g)', origin_time=4557.539332291027)
#                                         SortableClade(id=23, label='90 (g)', name='90 (g)', origin_time=4569.643050727937)
#                                         SortableClade(id=24, label='91 (e)', name='91 (e)', origin_time=4569.643050727937)
#                                     SortableClade(id=25, label='100 (j)', name='100 (j)', origin_time=4557.539332291027)
#                                         SortableClade(id=26, label='100 (j)', name='100 (j)', origin_time=4583.64488725544)
#                                             SortableClade(id=27, label='98 (e)', name='98 (e)', origin_time=4589.64488725544)
#                                             SortableClade(id=28, label='100 (j)', name='100 (j)', origin_time=4589.64488725544)
#                                                 SortableClade(id=29, label='99 (e)', name='99 (e)', origin_time=4594.64488725544)
#                                                 SortableClade(id=30, label='100 (j)', name='100 (j)', origin_time=4594.64488725544)
#                                         SortableClade(id=31, label='93 (e)', name='93 (e)', origin_time=4583.64488725544)
#                                             SortableClade(id=32, label='97 (h)', name='97 (h)', origin_time=4602.539330883132)
#                                             SortableClade(id=33, label='93 (e)', name='93 (e)', origin_time=4602.539330883132)
#                                                 SortableClade(id=34, label='96 (b)', name='96 (b)', origin_time=4617.680334812859)
#                                                 SortableClade(id=35, label='93 (e)', name='93 (e)', origin_time=4617.680334812859)
#                                                     SortableClade(id=36, label='93 (e)', name='93 (e)', origin_time=4627.680334812859)
#                                                     SortableClade(id=37, label='94 (e)', name='94 (e)', origin_time=4627.680334812859)
#                                                         SortableClade(id=38, label='94 (e)', name='94 (e)', origin_time=4636.2535489126)
#                                                         SortableClade(id=39, label='95 (b)', name='95 (b)', origin_time=4636.2535489126)
#                                 SortableClade(id=40, label='87 (e)', name='87 (e)', origin_time=4530.622794623638)
#                                     SortableClade(id=41, label='87 (e)', name='87 (e)', origin_time=4561.249580285865)
#                                     SortableClade(id=42, label='89 (g)', name='89 (g)', origin_time=4561.249580285865)
#                                         SortableClade(id=43, label='89 (g)', name='89 (g)', origin_time=4586.734870160614)
#                                         SortableClade(id=44, label='92 (i)', name='92 (i)', origin_time=4586.734870160614)
#                         SortableClade(id=45, label='78 (e)', name='78 (e)', origin_time=4457.572860866001)
#                             SortableClade(id=46, label='78 (e)', name='78 (e)', origin_time=4529.844916323142)
#                             SortableClade(id=47, label='80 (e)', name='80 (e)', origin_time=4529.844916323142)
#                     SortableClade(id=48, label='23 (e)', name='23 (e)', origin_time=4384.258469372925)
#                         SortableClade(id=49, label='74 (i)', name='74 (i)', origin_time=4491.617679504147)
#                         SortableClade(id=50, label='23 (e)', name='23 (e)', origin_time=4491.617679504147)
#                             SortableClade(id=51, label='69 (g)', name='69 (g)', origin_time=4583.666579551894)
#                                 SortableClade(id=52, label='81 (e)', name='81 (e)', origin_time=4656.640890100196)
#                                 SortableClade(id=53, label='69 (g)', name='69 (g)', origin_time=4656.640890100196)
#                                     SortableClade(id=54, label='79 (g)', name='79 (g)', origin_time=4726.193028816414)
#                                     SortableClade(id=55, label='69 (g)', name='69 (g)', origin_time=4726.193028816414)
#                                         SortableClade(id=56, label='75 (i)', name='75 (i)', origin_time=4789.7540231446965)
#                                             SortableClade(id=57, label='75 (i)', name='75 (i)', origin_time=4813.2540231446965)
#                                             SortableClade(id=58, label='76 (g)', name='76 (g)', origin_time=4813.2540231446965)
#                                                 SortableClade(id=59, label='76 (g)', name='76 (g)', origin_time=4819.2540231446965)
#                                                 SortableClade(id=60, label='77 (i)', name='77 (i)', origin_time=4819.2540231446965)
#                                         SortableClade(id=61, label='69 (g)', name='69 (g)', origin_time=4789.7540231446965)
#                                             SortableClade(id=62, label='72 (e)', name='72 (e)', origin_time=4839.92373512314)
#                                                 SortableClade(id=63, label='72 (e)', name='72 (e)', origin_time=4852.92373512314)
#                                                 SortableClade(id=64, label='73 (g)', name='73 (g)', origin_time=4852.92373512314)
#                                             SortableClade(id=65, label='69 (g)', name='69 (g)', origin_time=4839.92373512314)
#                                                 SortableClade(id=66, label='69 (g)', name='69 (g)', origin_time=4887.008764591114)
#                                                 SortableClade(id=67, label='71 (e)', name='71 (e)', origin_time=4887.008764591114)
#                             SortableClade(id=68, label='23 (e)', name='23 (e)', origin_time=4583.666579551894)
#                                 SortableClade(id=69, label='23 (e)', name='23 (e)', origin_time=4674.194199646537)
#                                     SortableClade(id=70, label='29 (e)', name='29 (e)', origin_time=4730.29232795756)
#                                         SortableClade(id=71, label='29 (e)', name='29 (e)', origin_time=4755.846192635921)
#                                         SortableClade(id=72, label='30 (e)', name='30 (e)', origin_time=4755.846192635921)
#                                     SortableClade(id=73, label='23 (e)', name='23 (e)', origin_time=4730.29232795756)
#                                         SortableClade(id=74, label='28 (b)', name='28 (b)', origin_time=4785.267322273157)
#                                         SortableClade(id=75, label='23 (e)', name='23 (e)', origin_time=4785.267322273157)
#                                             SortableClade(id=76, label='23 (e)', name='23 (e)', origin_time=4829.73360163179)
#                                                 SortableClade(id=77, label='24 (e)', name='24 (e)', origin_time=4859.783560034424)
#                                                     SortableClade(id=78, label='24 (e)', name='24 (e)', origin_time=4886.74649755985)
#                                                     SortableClade(id=79, label='26 (b)', name='26 (b)', origin_time=4886.74649755985)
#                                                 SortableClade(id=80, label='23 (e)', name='23 (e)', origin_time=4859.783560034424)
#                                                     SortableClade(id=81, label='27 (e)', name='27 (e)', origin_time=4888.792179443145)
#                                                     SortableClade(id=82, label='23 (e)', name='23 (e)', origin_time=4888.792179443145)
#                                                         SortableClade(id=83, label='23 (e)', name='23 (e)', origin_time=4908.445423450178)
#                                                         SortableClade(id=84, label='25 (e)', name='25 (e)', origin_time=4908.445423450178)
#                                             SortableClade(id=85, label='31 (e)', name='31 (e)', origin_time=4829.73360163179)
#                                                 SortableClade(id=86, label='31 (e)', name='31 (e)', origin_time=4874.177386349116)
#                                                 SortableClade(id=87, label='32 (e)', name='32 (e)', origin_time=4874.177386349116)
#                                                     SortableClade(id=88, label='32 (e)', name='32 (e)', origin_time=4918.302209294937)
#                                                     SortableClade(id=89, label='34 (e)', name='34 (e)', origin_time=4918.302209294937)
#                                                         SortableClade(id=90, label='34 (e)', name='34 (e)', origin_time=4937.275875255947)
#                                                         SortableClade(id=91, label='35 (e)', name='35 (e)', origin_time=4937.275875255947)
#                                 SortableClade(id=92, label='33 (e)', name='33 (e)', origin_time=4674.194199646537)
#                                     SortableClade(id=93, label='39 (f)', name='39 (f)', origin_time=4746.552682217691)
#                                         SortableClade(id=94, label='39 (f)', name='39 (f)', origin_time=4782.091393505524)
#                                         SortableClade(id=95, label='41 (e)', name='41 (e)', origin_time=4782.091393505524)
#                                             SortableClade(id=96, label='41 (e)', name='41 (e)', origin_time=4815.441805796829)
#                                             SortableClade(id=97, label='43 (e)', name='43 (e)', origin_time=4815.441805796829)
#                                     SortableClade(id=98, label='33 (e)', name='33 (e)', origin_time=4746.552682217691)
#                                         SortableClade(id=99, label='33 (e)', name='33 (e)', origin_time=4814.013782119782)
#                                         SortableClade(id=100, label='36 (e)', name='36 (e)', origin_time=4814.013782119782)
#                                             SortableClade(id=101, label='36 (e)', name='36 (e)', origin_time=4881.054814331406)
#                                                 SortableClade(id=102, label='36 (e)', name='36 (e)', origin_time=4931.069812082081)
#                                                     SortableClade(id=103, label='38 (e)', name='38 (e)', origin_time=4954.728848410723)
#                                                     SortableClade(id=104, label='36 (e)', name='36 (e)', origin_time=4954.728848410723)
#                                                         SortableClade(id=105, label='36 (e)', name='36 (e)', origin_time=4970.85336390732)
#                                                         SortableClade(id=106, label='37 (e)', name='37 (e)', origin_time=4970.85336390732)
#                                                 SortableClade(id=107, label='40 (e)', name='40 (e)', origin_time=4931.069812082081)
#                                                     SortableClade(id=108, label='56 (g)', name='56 (g)', origin_time=4980.851836950501)
#                                                         SortableClade(id=109, label='56 (g)', name='56 (g)', origin_time=5007.563257728887)
#                                                             SortableClade(id=110, label='56 (g)', name='56 (g)', origin_time=5021.419664189438)
#                                                             SortableClade(id=111, label='57 (g)', name='57 (g)', origin_time=5021.419664189438)
#                                                         SortableClade(id=112, label='59 (h)', name='59 (h)', origin_time=5007.563257728887)
#                                                             SortableClade(id=113, label='62 (g)', name='62 (g)', origin_time=5027.152795753047)
#                                                             SortableClade(id=114, label='59 (h)', name='59 (h)', origin_time=5027.152795753047)
#                                                                 SortableClade(id=115, label='59 (h)', name='59 (h)', origin_time=5046.342636815442)
#                                                                 SortableClade(id=116, label='60 (g)', name='60 (g)', origin_time=5046.342636815442)
#                                                                     SortableClade(id=117, label='60 (g)', name='60 (g)', origin_time=5059.533542773715)
#                                                                     SortableClade(id=118, label='61 (e)', name='61 (e)', origin_time=5059.533542773715)
#                                                     SortableClade(id=119, label='40 (e)', name='40 (e)', origin_time=4980.851836950501)
#                                                         SortableClade(id=120, label='58 (g)', name='58 (g)', origin_time=5029.788019882969)
#                                                         SortableClade(id=121, label='40 (e)', name='40 (e)', origin_time=5029.788019882969)
#                                                             SortableClade(id=122, label='40 (e)', name='40 (e)', origin_time=5071.23376755387)
#                                                             SortableClade(id=123, label='42 (e)', name='42 (e)', origin_time=5071.23376755387)
#                                                                 SortableClade(id=124, label='45 (g)', name='45 (g)', origin_time=5110.6228523363325)
#                                                                     SortableClade(id=125, label='45 (g)', name='45 (g)', origin_time=5147.204951784013)
#                                                                         SortableClade(id=126, label='48 (g)', name='48 (g)', origin_time=5163.552734508285)
#                                                                         SortableClade(id=127, label='45 (g)', name='45 (g)', origin_time=5163.552734508285)
#                                                                             SortableClade(id=128, label='45 (g)', name='45 (g)', origin_time=5174.833248680963)
#                                                                             SortableClade(id=129, label='46 (g)', name='46 (g)', origin_time=5174.833248680963)
#                                                                                 SortableClade(id=130, label='46 (g)', name='46 (g)', origin_time=5184.50278848387)
#                                                                                 SortableClade(id=131, label='47 (g)', name='47 (g)', origin_time=5184.50278848387)
#                                                                     SortableClade(id=132, label='49 (g)', name='49 (g)', origin_time=5147.204951784013)
#                                                                         SortableClade(id=133, label='54 (g)', name='54 (g)', origin_time=5172.364443034831)
#                                                                         SortableClade(id=134, label='49 (g)', name='49 (g)', origin_time=5172.364443034831)
#                                                                             SortableClade(id=135, label='55 (g)', name='55 (g)', origin_time=5196.961190787329)
#                                                                             SortableClade(id=136, label='49 (g)', name='49 (g)', origin_time=5196.961190787329)
#                                                                                 SortableClade(id=137, label='49 (g)', name='49 (g)', origin_time=5219.388852279334)
#                                                                                 SortableClade(id=138, label='50 (g)', name='50 (g)', origin_time=5219.388852279334)
#                                                                                     SortableClade(id=139, label='50 (g)', name='50 (g)', origin_time=5240.883037539539)
#                                                                                         SortableClade(id=140, label='50 (g)', name='50 (g)', origin_time=5251.837488689643)
#                                                                                         SortableClade(id=141, label='51 (g)', name='51 (g)', origin_time=5251.837488689643)
#                                                                                     SortableClade(id=142, label='52 (g)', name='52 (g)', origin_time=5240.883037539539)
#                                                                                         SortableClade(id=143, label='52 (g)', name='52 (g)', origin_time=5258.087688073624)
#                                                                                         SortableClade(id=144, label='53 (e)', name='53 (e)', origin_time=5258.087688073624)
#                                                                 SortableClade(id=145, label='42 (e)', name='42 (e)', origin_time=5110.6228523363325)
#                                                                     SortableClade(id=146, label='42 (e)', name='42 (e)', origin_time=5148.6294307142925)
#                                                                     SortableClade(id=147, label='44 (e)', name='44 (e)', origin_time=5148.6294307142925)
#                                             SortableClade(id=148, label='63 (g)', name='63 (g)', origin_time=4881.054814331406)
#                                                 SortableClade(id=149, label='70 (e)', name='70 (e)', origin_time=4934.787951221039)
#                                                 SortableClade(id=150, label='63 (g)', name='63 (g)', origin_time=4934.787951221039)
#                                                     SortableClade(id=151, label='68 (e)', name='68 (e)', origin_time=4969.855742711237)
#                                                     SortableClade(id=152, label='63 (g)', name='63 (g)', origin_time=4969.855742711237)
#                                                         SortableClade(id=153, label='67 (g)', name='67 (g)', origin_time=5004.762762062652)
#                                                         SortableClade(id=154, label='63 (g)', name='63 (g)', origin_time=5004.762762062652)
#                                                             SortableClade(id=155, label='64 (e)', name='64 (e)', origin_time=5030.467819930705)
#                                                                 SortableClade(id=156, label='64 (e)', name='64 (e)', origin_time=5039.687364387998)
#                                                                 SortableClade(id=157, label='65 (e)', name='65 (e)', origin_time=5039.687364387998)
#                                                             SortableClade(id=158, label='63 (g)', name='63 (g)', origin_time=5030.467819930705)
#                                                                 SortableClade(id=159, label='63 (g)', name='63 (g)', origin_time=5050.417757273965)
#                                                                 SortableClade(id=160, label='66 (g)', name='66 (g)', origin_time=5050.417757273965)
#                 SortableClade(id=161, label='12 (b)', name='12 (b)', origin_time=4269.005486765098)
#                     SortableClade(id=162, label='12 (b)', name='12 (b)', origin_time=4397.13140139598)
#                     SortableClade(id=163, label='13 (b)', name='13 (b)', origin_time=4397.13140139598)
#                         SortableClade(id=164, label='22 (e)', name='22 (e)', origin_time=4462.6123146455675)
#                         SortableClade(id=165, label='13 (b)', name='13 (b)', origin_time=4462.6123146455675)
#                             SortableClade(id=166, label='13 (b)', name='13 (b)', origin_time=4520.430996747463)
#                                 SortableClade(id=167, label='14 (d)', name='14 (d)', origin_time=4561.897850980694)
#                                 SortableClade(id=168, label='13 (b)', name='13 (b)', origin_time=4561.897850980694)
#                                     SortableClade(id=169, label='16 (e)', name='16 (e)', origin_time=4601.5746704096755)
#                                     SortableClade(id=170, label='13 (b)', name='13 (b)', origin_time=4601.5746704096755)
#                                         SortableClade(id=171, label='13 (b)', name='13 (b)', origin_time=4626.937044115621)
#                                         SortableClade(id=172, label='15 (e)', name='15 (e)', origin_time=4626.937044115621)
#                             SortableClade(id=173, label='17 (e)', name='17 (e)', origin_time=4520.430996747463)
#                                 SortableClade(id=174, label='18 (e)', name='18 (e)', origin_time=4569.000534525786)
#                                     SortableClade(id=175, label='18 (e)', name='18 (e)', origin_time=4587.828704909549)
#                                     SortableClade(id=176, label='19 (e)', name='19 (e)', origin_time=4587.828704909549)
#                                 SortableClade(id=177, label='17 (e)', name='17 (e)', origin_time=4569.000534525786)
#                                     SortableClade(id=178, label='17 (e)', name='17 (e)', origin_time=4611.077844325724)
#                                     SortableClade(id=179, label='20 (e)', name='20 (e)', origin_time=4611.077844325724)
#                                         SortableClade(id=180, label='20 (e)', name='20 (e)', origin_time=4624.642504291975)
#                                         SortableClade(id=181, label='21 (e)', name='21 (e)', origin_time=4624.642504291975)
#             SortableClade(id=182, label='10 (b)', name='10 (b)', origin_time=4137.762391708634)
#                 SortableClade(id=183, label='2 (c)', name='2 (c)', origin_time=4300.765459164433)
#                 SortableClade(id=184, label='10 (b)', name='10 (b)', origin_time=4300.765459164433)
#                     SortableClade(id=185, label='10 (b)', name='10 (b)', origin_time=4409.09827967604)
#                         SortableClade(id=186, label='10 (b)', name='10 (b)', origin_time=4446.541570129738)
#                         SortableClade(id=187, label='11 (b)', name='11 (b)', origin_time=4446.541570129738)
#                     SortableClade(id=188, label='3 (b)', name='3 (b)', origin_time=4409.09827967604)
#                         SortableClade(id=189, label='8 (b)', name='8 (b)', origin_time=4513.036963523778)
#                         SortableClade(id=190, label='3 (b)', name='3 (b)', origin_time=4513.036963523778)
#                             SortableClade(id=191, label='5 (b)', name='5 (b)', origin_time=4614.05305135141)
#                                 SortableClade(id=192, label='5 (b)', name='5 (b)', origin_time=4696.1338042719335)
#                                 SortableClade(id=193, label='9 (b)', name='9 (b)', origin_time=4696.1338042719335)
#                             SortableClade(id=194, label='3 (b)', name='3 (b)', origin_time=4614.05305135141)
#                                 SortableClade(id=195, label='3 (b)', name='3 (b)', origin_time=4711.131627772782)
#                                 SortableClade(id=196, label='4 (b)', name='4 (b)', origin_time=4711.131627772782)
#                                     SortableClade(id=197, label='4 (b)', name='4 (b)', origin_time=4778.083102737864)
#                                     SortableClade(id=198, label='6 (b)', name='6 (b)', origin_time=4778.083102737864)
#                                         SortableClade(id=199, label='6 (b)', name='6 (b)', origin_time=4809.9186174973265)
#                                         SortableClade(id=200, label='7 (b)', name='7 (b)', origin_time=4809.9186174973265)
